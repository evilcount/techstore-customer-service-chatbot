# %% [markdown]
# # Python Jupyter Starter
#
# This notebook contains a minimal Python example for exploration and testing.

# %%
import math

def greet(name):
    return f"Hello, {name}! Welcome to Python in Jupyter."

print(greet('Developer'))
print('Pi to 5 decimal places:', round(math.pi, 5))
